# %% [markdown]
# #Set up Kaggle and download dataset to drive for first time
# (This part of code is intentionally commented)

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
#  ! pip install -q kaggle

# %%
# import os
# os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"

# %%
# %cd /content/gdrive/My Drive/Kaggle

# %%
# ! kaggle datasets download -d grassknoted/asl-alphabet
# Out:
# ...
#  99% 1.01G/1.03G [00:11<00:00, 108MB/s]
# 100% 1.03G/1.03G [00:11<00:00, 98.2MB/s]

# %%
# %cd /content
# Out:
# /content

# %% [markdown]
# # Set up train and test data using Kaggle ASL dataset

# %%
# !gdown --id 1BikY7qVjADK4UxZIwckcpOMeeHW6UMGK
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BikY7qVjADK4UxZIwckcpOMeeHW6UMGK
# To: /content/asl-alphabet.zip
# 1.10GB [00:09, 116MB/s]

# %%
# !unzip -q /content/asl-alphabet.zip

# %% [markdown]
# # Training

# %%
import os
import tensorflow as tf
import keras
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pandas as pd
import skimage
from skimage.transform import resize

# %%
train_dir = r'/content/asl_alphabet_train/asl_alphabet_train'
